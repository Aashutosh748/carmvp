# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # Dataset

# %%
auto = pd.read_csv("Automobile price data _Raw_.csv") #pandas reads the csv data

# %%
 auto.describe() #we can now see the different attributes along with the details
# Out:
#         symboling  wheel-base      length       width      height  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000
# mean     0.834146   98.756585  174.049268   65.907805   53.724878
# std      1.245307    6.021776   12.337289    2.145204    2.443522
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.100000   52.000000
# 50%      1.000000   97.000000  173.200000   65.500000   54.100000
# 75%      2.000000  102.400000  183.100000   66.900000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#        curb-weight  engine-size  compression-ratio    city-mpg  highway-mpg
# count   205.000000   205.000000         205.000000  205.000000   205.000000
# mean   2555.565854   126.907317          10.142537   25.219512    30.751220
# std     520.680204    41.642693           3.972040    6.542142     6.886443
# ...

# %%
auto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
# symboling            205 non-null int64
# normalized-losses    205 non-null object
# make                 205 non-null object
# fuel-type            205 non-null object
# aspiration           205 non-null object
# num-of-doors         205 non-null object
# body-style           205 non-null object
# drive-wheels         205 non-null object
# engine-location      205 non-null object
# wheel-base           205 non-null float64
# length               205 non-null float64
# width                205 non-null float64
# height               205 non-null float64
# curb-weight          205 non-null int64
# engine-type          205 non-null object
# num-of-cylinders     205 non-null object
# engine-size          205 non-null int64
# fuel-system          205 non-null object
# bore                 205 non-null object
# stroke               205 non-null object
# ...

# %% [markdown]
# auto.head() #let's now look at the datasets actually

# %% [markdown]
# we see some data is missing there, taking that in account lets see the whole dataset to figure out how many is really missing.

# %%
auto #looking to whole dataset
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# 5            2                 ?         audi       gas        std
# 6            1               158         audi       gas        std
# 7            1                 ?         audi       gas        std
# 8            1               158         audi       gas      turbo
# 9            0                 ?         audi       gas      turbo
# 10           2               192          bmw       gas        std
# 11           0               192          bmw       gas        std
# 12           0               188          bmw       gas        std
# ...

# %% [markdown]
# ### By looking at the datasets
# #### 1. Judging by the attributes we see our target attribute is price.
# #### 2. Analysing the datasets we see it is a regression problem.
# #### 3. Some of the prices are missing, so we need to fix that also.

# %% [markdown]
# ## making data useful/complete

# %%
df = pd.DataFrame(auto)
df ['price'] = pd.to_numeric(df['price'], errors='coerce')
df = df.replace(np.nan, 0, regex=True)

# %%
df
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# 5            2                 ?         audi       gas        std
# 6            1               158         audi       gas        std
# 7            1                 ?         audi       gas        std
# 8            1               158         audi       gas      turbo
# 9            0                 ?         audi       gas      turbo
# 10           2               192          bmw       gas        std
# 11           0               192          bmw       gas        std
# 12           0               188          bmw       gas        std
# ...

# %%
#if we check now (9th column) the unlisted ? is now changed by 0
#but keeping the price to 0 for legit features of a car is not justified, so to fix that

# %%
np.average(df.price)
# Out:
# 12949.429268292683

# %%
df = df.replace(0, 12949.429268292683, regex=True)

# %%
df.head(10)
# Out:
#       symboling normalized-losses         make fuel-type aspiration  \
# 0      3.000000                 ?  alfa-romero       gas        std
# 1      3.000000                 ?  alfa-romero       gas        std
# 2      1.000000                 ?  alfa-romero       gas        std
# 3      2.000000               164         audi       gas        std
# 4      2.000000               164         audi       gas        std
# 5      2.000000                 ?         audi       gas        std
# 6      1.000000               158         audi       gas        std
# 7      1.000000                 ?         audi       gas        std
# 8      1.000000               158         audi       gas      turbo
# 9  12949.429268                 ?         audi       gas      turbo
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  \
# 0          two  convertible          rwd           front        88.6
# 1          two  convertible          rwd           front        88.6
# ...

# %%
#so now prices has been updated.

# %% [markdown]
# # Exploratory Data Analysis

# %%
ezvpjoin = plt.figure(figsize=(10, 9))
sns.set_palette("GnBu_d")
sns.set_style('whitegrid')

sns.jointplot(x='engine-size',y='price',data=df)
ezvpjoin.savefig("ezvpjoin.png", dpi=100)

# %%
sns.jointplot(x='wheel-base',y='price',data=df)

# %%
sns.jointplot(x='city-mpg',y='price', kind='hex', data=df)

# %%
plt.figure(figsize=(18, 7))
sns.boxplot(x='engine-size',y='price',data=df,palette='winter')

# %%
plt.figure(figsize=(18, 7))
sns.countplot(x='price',data=df)

# %% [markdown]
# #### So now after seeing the pattern we are confirmed we can apply regression on the dataset and find some more meaningful insights

# %% [markdown]
# #### Still idea isn't very clear how can we train it in efficient manner so,

# %%
sns.pairplot(df)

# %% [markdown]
# ## It is now very clear that engine-size and wheel-base is showing direct relationship with the increase of the cost however engine-size is a significant attribute which can be linked to the price as it contributes more value to our model.

# %%
plt.figure(figsize=(10, 10))
sns.heatmap(df.corr(),annot=True) #to check the co-relation

# %%
sns.lmplot(x='engine-size',y='price',data=df)

# %% [markdown]
# ## This is our Regression Line

# %% [markdown]
# # Preparing data for Training

# %%
y=df['price']

# %%
x=df[['wheel-base','engine-size','city-mpg']]

# %% [markdown]
# # Training the Model

# %%
from sklearn.model_selection import  train_test_split

x_train,x_test,y_train,y_test = train_test_split(x,y, test_size=0.3, random_state=101)

# %%
from sklearn.linear_model import LinearRegression

lm = LinearRegression()

lm.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
print("coefficients: \n", lm.coef_)
# Out:
# coefficients:
#  [ 146.37237053  121.39782668 -220.08545067]

# %% [markdown]
# # Testing the Model

# %%
prediction = lm.predict(x_test)

# %%
plt.scatter(y_test,prediction)
plt.xlabel('y_test')
plt.ylabel('Prices')
# Out:
# Text(0,0.5,'Prices')

# %% [markdown]
# ### Algorithm 1 LinearRegression from sciket learn

# %%
from sklearn import metrics #LinearRegression from sciket learn

print('MAE:', metrics.mean_absolute_error(y_test, prediction))
print('MSE:', metrics.mean_squared_error(y_test, prediction))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, prediction)))
# Out:
# MAE: 2277.3819825
# MSE: 11143975.46
# RMSE: 3338.25934583

# %%
import sklearn.metrics as metric
metric.r2_score(y_test,prediction) #r2 score
# Out:
# 0.83565206787682855

# %%
sns.distplot((y_test-prediction),bins=50);

# %% [markdown]
# ### Algorithm 2 LinearRegression from Decision Trees

# %% [markdown]
# data = pd.read_csv('Automobile price data _Raw_.csv')
# df = pd.DataFrame(data)
# df ['price'] = pd.to_numeric(df['price'], errors='coerce')
# df = df.replace(np.nan, 0, regex=True)
# df = df.replace(0, 12949.429268292683, regex=True)
# X = df['engine-size'].values
# y = df['price'].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3)

# %%
# Fitting Decision Tree Regression to the dataset
from sklearn.tree import DecisionTreeRegressor
regressor = DecisionTreeRegressor()
regressor.fit(X_train.reshape(-1,1), y_train.reshape(-1,1))
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=None, splitter='best')

# %%
y_pred = regressor.predict(X_test.reshape(-1,1))
y_pred
# Out:
# array([  7114.80365854,   8411.66666667,  16503.        ,  22835.        ,
#          5945.        ,   6773.5       ,   6773.5       ,  12295.        ,
#         17332.5       ,  27325.33333333,   8411.66666667,   6773.5       ,
#          9784.25      ,  10275.625     ,   6773.5       ,   9784.25      ,
#         15945.        ,  10275.625     ,  23875.        ,  22835.        ,
#         16387.5       ,  12009.        ,  12534.6       ,   9612.54545455,
#          9784.25      ,  15945.        ,   9612.54545455,   6773.5       ,
#         36318.33333333,  15945.        ,  15844.        ,  10275.625     ,
#         16459.        ,   7889.11111111,   6773.5       ,  10275.625     ,
#          6773.5       ,  10416.66666667,  12534.6       ,   8411.66666667,
#         12295.        ,   5399.        ,  32250.        ,  10275.625     ,
#          5945.        ,   7114.80365854,   8411.66666667,   8411.66666667,
# ...

# %%
dt = pd.DataFrame({'Engine-size':y_test.reshape(-1), 'Price':y_pred.reshape(-1)})
dt
# Out:
#      Engine-size         Price
# 0    5572.000000   7114.803659
# 1    6849.000000   8411.666667
# 2   18280.000000  16503.000000
# 3   15750.000000  22835.000000
# 4    7395.000000   5945.000000
# 5    5389.000000   6773.500000
# 6    6855.000000   6773.500000
# 7   11845.000000  12295.000000
# 8   13295.000000  17332.500000
# 9   31600.000000  27325.333333
# 10   5499.000000   8411.666667
# 11   7295.000000   6773.500000
# 12   7895.000000   9784.250000
# 13   7053.000000  10275.625000
# 14   7295.000000   6773.500000
# 15   7898.000000   9784.250000
# 16  17950.000000  15945.000000
# 17  16925.000000  10275.625000
# 18  12949.429268  23875.000000
# 19  20970.000000  22835.000000
# 20  19045.000000  16387.500000
# 21   8449.000000  12009.000000
# 22  16630.000000  12534.600000
# 23  10795.000000   9612.545455
# 24   9959.000000   9784.250000
# 25  16500.000000  15945.000000
# 26   8948.000000   9612.545455
# 27   6488.000000   6773.500000
# 28  12949.429268  36318.333333
# ...

# %%
# Visualising the Decision Tree Regression Results 
X_grid = np.arange(min(X), max(X), 0.01)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X_test, y_test, color = 'red')
plt.scatter(X_test, y_pred, color = 'green')
plt.title('Decision Tree Regression')
plt.xlabel("Engine-size")
plt.ylabel('Price')
plt.show()

# %% [markdown]
# #### In this graph, the Real values are plotted with “Red” color and the Predicted values are plotted with “Green” color. The plot of the Decision Tree Regression model is also drawn in “Black” color.

# %%
plt.plot(X_grid, regressor.predict(X_grid), color = 'black')
plt.title('Decision Tree Regression')
plt.xlabel('Engine-size')
plt.ylabel('Price')
plt.show()

# %%
prediction = lm.predict(x_test)

# %%
plt.scatter(y_test,prediction)
plt.xlabel('engine-size')
plt.ylabel('Prices')
# Out:
# Text(0,0.5,'Prices')

# %%
import sklearn.metrics as metric
metric.r2_score(y_test,prediction) #r2 score
# Out:
# -0.67211037802025575

# %% [markdown]
# ### Algorithm 3 LinearRegression from Random Forest

# %%
data = pd.read_csv("Automobile price data _Raw_.csv")

# %%
df = pd.DataFrame(data)
df ['price'] = pd.to_numeric(df['price'], errors='coerce')
df = df.replace(np.nan, 0, regex=True)
df = df.replace(0, 12949.429268292683, regex=True)

# %%
X = df['engine-size'].values
y = df['price'].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3)

# %%
# Fitting Random Forest Regression to the dataset
from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 10, random_state = 0)
regressor.fit(X_train.reshape(-1,1), y_train.reshape(-1,1))
# Out:
# C:\Users\Aashutosh\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   after removing the cwd from sys.path.
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#            oob_score=False, random_state=0, verbose=0, warm_start=False)

# %%
y_pred = regressor.predict(X_test.reshape(-1,1))
y_pred
# Out:
# array([ 16864.6       ,   9809.97461927,   7815.24533578,   8344.80695644,
#          9626.9897619 ,  13108.21071429,   9809.97461927,   9901.4001715 ,
#          9901.4001715 ,  14745.63      ,  18133.83333333,   7815.24533578,
#         13749.94166667,  16214.91071429,   9626.9897619 ,  34747.        ,
#          7815.24533578,  16864.6       ,  17093.25      ,   8344.80695644,
#         26667.2       ,   6681.329017  ,  40550.        ,   6806.04424869,
#          9901.4001715 ,  16044.1       ,   9626.9897619 ,  34747.        ,
#          9809.97461927,  16864.6       ,  14745.63      ,  26667.2       ,
#         12502.58333333,   8344.80695644,  16044.1       ,  10327.66051587,
#          7407.68009705,   9626.9897619 ,  13108.21071429,   7815.24533578,
#         16214.91071429,   8344.80695644,   6681.329017  ,  10327.66051587,
#          6806.04424869,  10327.66051587,   6806.04424869,  15854.70357143,
# ...

# %%
df = pd.DataFrame({'Real Values':y_test.reshape(-1), 'Predicted Values':y_pred.reshape(-1)})
df
# Out:
#     Predicted Values   Real Values
# 0       16864.600000  18950.000000
# 1        9809.974619   7895.000000
# 2        7815.245336   9298.000000
# 3        8344.806956   5499.000000
# 4        9626.989762   9960.000000
# 5       13108.210714   9549.000000
# 6        9809.974619   7788.000000
# 7        9901.400171   8189.000000
# 8        9901.400171   9988.000000
# 9       14745.630000  15510.000000
# 10      18133.833333  13499.000000
# 11       7815.245336   8358.000000
# 12      13749.941667  12764.000000
# 13      16214.910714  17710.000000
# 14       9626.989762  11259.000000
# 15      34747.000000  35056.000000
# 16       7815.245336   9258.000000
# 17      16864.600000   9295.000000
# 18      17093.250000  16845.000000
# 19       8344.806956   7299.000000
# 20      26667.200000  28248.000000
# 21       6681.329017   6695.000000
# 22      40550.000000  36000.000000
# 23       6806.044249   7295.000000
# 24       9901.400171   6989.000000
# 25      16044.100000  16558.000000
# ...

# %%
# Visualising the Random Forest Regression Results  
X_grid = np.arange(min(X), max(X), 0.01)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X_test, y_test, color = 'blue')
plt.scatter(X_test, y_pred, color = 'purple')
plt.title('Random Forest Regression')
plt.xlabel('engine-size')
plt.ylabel('price')
plt.show()

# %%
plt.plot(X_grid, regressor.predict(X_grid), color = 'green')
plt.title('Random Forest Regression')
plt.xlabel('engine-size')
plt.ylabel('price')
plt.show()

# %%
import sklearn.metrics as metric
metric.r2_score(y_test,y_pred) #r2 score
# Out:
# 0.84355058115325099

# %% [markdown]
# # Thank You!
